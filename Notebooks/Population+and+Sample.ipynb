# %% [markdown]
# ## Population and Sample

# %%
import pandas as pd
import numpy as np

# %%
# Create a Population DataFrame with 10 data 

data = pd.DataFrame()
data['Population'] = [47, 48, 85, 20, 19, 13, 72, 16, 50, 60]

# %% [markdown]
# You may get different results from sampling.

# %%
# Draw sample with replacement, size=5 from Population

a_sample_with_replacement = data['Population'].sample(5, replace=True)
print(a_sample_with_replacement)
# Out:
# 2    85
# 7    16
# 5    13
# 1    48
# 6    72
# Name: Population, dtype: int64

# %%
# Draw sample without replacement, size=5 from Population

a_sample_without_replacement = data['Population'].sample(5, replace=False)
print(a_sample_without_replacement)
# Out:
# 8    50
# 9    60
# 6    72
# 5    13
# 0    47
# Name: Population, dtype: int64

# %% [markdown]
# # Parameters and Statistics

# %%
# Calculate mean and variance
population_mean = data['Population'].mean()
population_var = data['Population'].var(ddof=0) # en este caso es 0 
print('Population mean is ', population_mean)
print('Population variance is', population_var)
# Out:
# Population mean is  43.0
# Population variance is 571.8

# %% [markdown]
# **Expected Output: ** Population mean is  43.0
# Population variance is 571.8

# %% [markdown]
# You may get different result from sampling.

# %%
# Calculate sample mean and sample standard deviation, size =10
# You will get different mean and varince every time when you excecute the below code

a_sample = data['Population'].sample(10, replace=True)
sample_mean = a_sample.mean()
sample_var = a_sample.var()
print('Sample mean is ', sample_mean)
print('Sample variance is', sample_var)
# Out:
# Sample mean is  42.0
# Sample variance is 628.222222222

# %% [markdown]
# # Average of an unbiased estimator

# %%
sample_length = 500
sample_variance_collection=[data['Population'].sample(10, replace=True).var(ddof=1) for i in range(sample_length)]

# %%
print('Sample variance is', sample_variance_collection)
# Out:
# Sample variance is [690.66666666666663, 870.17777777777781, 620.26666666666665, 473.34444444444449, 204.48888888888891, 313.15555555555557, 324.27777777777777, 488.05555555555554, 689.56666666666661, 612.67777777777781, 194.45555555555555, 605.06666666666672, 480.66666666666669, 687.12222222222215, 447.95555555555558, 556.32222222222219, 466.01111111111118, 1037.1111111111111, 706.72222222222217, 302.01111111111112, 510.71111111111105, 755.21111111111122, 673.61111111111109, 350.17777777777769, 613.78888888888878, 526.40000000000009, 489.60000000000008, 516.84444444444443, 271.56666666666666, 431.65555555555557, 568.32222222222242, 653.65555555555557, 410.10000000000002, 926.54444444444437, 635.33333333333337, 436.71111111111111, 495.43333333333328, 696.45555555555563, 728.22222222222217, 567.12222222222226, 460.67777777777781, 448.5, 544.62222222222215, 655.06666666666672, 242.72222222222223, 617.28888888888878, 536.76666666666688, 503.21111111111105, 725.56666666666661, 712.39999999999998, 275.61111111111109, 445.65555555555562, 927.33333333333337, 913.15555555555557, 783.